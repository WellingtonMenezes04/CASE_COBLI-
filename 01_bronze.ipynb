# %%
# Caminho do arquivo
file_path = "/Volumes/workspace/default/dados_brutos/acidentes_brasil.csv"

# Criar o DataFrame bronze
df_bronze = spark.read.csv(file_path, 
                           header=True, 
                           sep=";", 
                           inferSchema=False, 
                           encoding="utf-8")
# Visualizar
display(df_bronze)

# %%
df_bronze.dtypes
